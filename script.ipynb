# %%
from data import *

# %%
def damageToFloat(damages):
  res=[]
  for damage in damages:
    conversion = {'M':10**6, 'B': 10**9}
    ch = damage[-1]
    if damage[-1] in conversion:
      damageInFloat = float(damage[:-1])*conversion[ch]
    else:
      damageInFloat = damage
    res.append(damageInFloat)
  return res
updated_damages = damageToFloat(damages)
updated_damages
# Out:
# ['Damages not recorded',
#  100000000.0,
#  'Damages not recorded',
#  40000000.0,
#  27900000.0,
#  5000000.0,
#  'Damages not recorded',
#  306000000.0,
#  2000000.0,
#  65800000.0,
#  326000000.0,
#  60300000.0,
#  208000000.0,
#  1420000000.0,
#  25400000.0,
#  'Damages not recorded',
#  1540000000.0,
#  1240000000.0,
#  7100000000.0,
#  10000000000.0,
#  26500000000.0,
#  6200000000.0,
#  5370000000.0,
#  23300000000.0,
#  1010000000.0,
#  125000000000.0,
#  12000000000.0,
#  29400000000.0,
#  1760000000.0,
#  720000000.0,
#  15100000000.0,
#  64800000000.0,
#  91600000000.0,
#  25100000000.0]

# %%
def makeDict():
  hurricanes={}
  for idx in range(len(names)):
    hurricanes[names[idx]] = {"name": names[idx],
                              "month": months[idx],
                              "year": years[idx],
                              "maxWind": max_sustained_winds[idx],
                              "areas": areas_affected[idx],
                              "damage": updated_damages[idx],
                              "deaths": deaths[idx]}
  return hurricanes
hurricanes = makeDict()
hurricanes
# Out:
# {'Cuba I': {'name': 'Cuba I',
#   'month': 'October',
#   'year': 1924,
#   'maxWind': 165,
#   'areas': ['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'],
#   'damage': 'Damages not recorded',
#   'deaths': 90},
#  'San Felipe II Okeechobee': {'name': 'San Felipe II Okeechobee',
#   'month': 'September',
#   'year': 1928,
#   'maxWind': 160,
#   'areas': ['Lesser Antilles',
#    'The Bahamas',
#    'United States East Coast',
#    'Atlantic Canada'],
#   'damage': 100000000.0,
#   'deaths': 4000},
#  'Bahamas': {'name': 'Bahamas',
#   'month': 'September',
#   'year': 1932,
#   'maxWind': 160,
#   'areas': ['The Bahamas', 'Northeastern United States'],
#   'damage': 'Damages not recorded',
#   'deaths': 16},
#  'Cuba II': {'name': 'Cuba II',
#   'month': 'November',
#   'year': 1932,
#   'maxWind': 175,
#   'areas': ['Lesser Antilles',
#    'Jamaica',
#    'Cayman Islands',
#    'Cuba',
#    'The Bahamas',
#    'Bermuda'],
#   'damage': 40000000.0,
#   'deaths': 3103},
#  'CubaBrownsville': {'name': 'CubaBrownsville',
#   'month': 'August',
#   'year': 1933,
#   'maxWind': 160,
#   'areas': ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'],
#   'damage': 27900000.0,
#   'deaths': 179},
#  'Tampico': {'name': 'Tampico',
#   'month': 'September',
#   'year': 1933,
#   'maxWind': 160,
#   'areas': ['Jamaica', 'Yucatn Peninsula'],
#   'damage': 5000000.0,
#   'deaths': 184},
#  'Labor Day': {'name': 'Labor Day',
#   'month': 'September',
#   'year': 1935,
#   'maxWind': 185,
#   'areas': ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'],
#   'damage': 'Damages not recorded',
#   'deaths': 408},
#  'New England': {'name': 'New England',
#   'month': 'September',
#   'year': 1938,
#   'maxWind': 160,
#   'areas': ['Southeastern United States',
#    'Northeastern United States',
#    'Southwestern Quebec'],
#   'damage': 306000000.0,
#   'deaths': 682},
#  'Carol': {'name': 'Carol',
#   'month': 'September',
#   'year': 1953,
#   'maxWind': 160,
#   'areas': ['Bermuda', 'New England', 'Atlantic Canada'],
#   'damage': 2000000.0,
#   'deaths': 5},
#  'Janet': {'name': 'Janet',
#   'month': 'September',
#   'year': 1955,
#   'maxWind': 175,
#   'areas': ['Lesser Antilles', 'Central America'],
#   'damage': 65800000.0,
#   'deaths': 1023},
#  'Carla': {'name': 'Carla',
#   'month': 'September',
#   'year': 1961,
#   'maxWind': 175,
#   'areas': ['Texas', 'Louisiana', 'Midwestern United States'],
#   'damage': 326000000.0,
#   'deaths': 43},
#  'Hattie': {'name': 'Hattie',
#   'month': 'October',
#   'year': 1961,
#   'maxWind': 160,
#   'areas': ['Central America'],
#   'damage': 60300000.0,
#   'deaths': 319},
#  'Beulah': {'name': 'Beulah',
#   'month': 'September',
#   'year': 1967,
#   'maxWind': 160,
#   'areas': ['The Caribbean', 'Mexico', 'Texas'],
#   'damage': 208000000.0,
#   'deaths': 688},
#  'Camille': {'name': 'Camille',
#   'month': 'August',
#   'year': 1969,
#   'maxWind': 175,
#   'areas': ['Cuba', 'United States Gulf Coast'],
#   'damage': 1420000000.0,
#   'deaths': 259},
#  'Edith': {'name': 'Edith',
#   'month': 'September',
#   'year': 1971,
#   'maxWind': 160,
#   'areas': ['The Caribbean',
#    'Central America',
#    'Mexico',
#    'United States Gulf Coast'],
#   'damage': 25400000.0,
#   'deaths': 37},
#  'Anita': {'name': 'Anita',
#   'month': 'September',
#   'year': 1977,
#   'maxWind': 175,
#   'areas': ['Mexico'],
#   'damage': 'Damages not recorded',
#   'deaths': 11},
#  'David': {'name': 'David',
#   'month': 'August',
#   'year': 1979,
#   'maxWind': 175,
#   'areas': ['The Caribbean', 'United States East coast'],
#   'damage': 1540000000.0,
#   'deaths': 2068},
#  'Allen': {'name': 'Allen',
#   'month': 'August',
#   'year': 1980,
#   'maxWind': 190,
#   'areas': ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'],
#   'damage': 1240000000.0,
#   'deaths': 269},
#  'Gilbert': {'name': 'Gilbert',
#   'month': 'September',
#   'year': 1988,
#   'maxWind': 185,
#   'areas': ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'],
#   'damage': 7100000000.0,
#   'deaths': 318},
#  'Hugo': {'name': 'Hugo',
#   'month': 'September',
#   'year': 1989,
#   'maxWind': 160,
#   'areas': ['The Caribbean', 'United States East Coast'],
#   'damage': 10000000000.0,
#   'deaths': 107},
#  'Andrew': {'name': 'Andrew',
#   'month': 'August',
#   'year': 1992,
#   'maxWind': 175,
#   'areas': ['The Bahamas', 'Florida', 'United States Gulf Coast'],
#   'damage': 26500000000.0,
#   'deaths': 65},
#  'Mitch': {'name': 'Mitch',
#   'month': 'October',
#   'year': 1998,
#   'maxWind': 180,
#   'areas': ['Central America', 'Yucatn Peninsula', 'South Florida'],
#   'damage': 6200000000.0,
#   'deaths': 19325},
#  'Isabel': {'name': 'Isabel',
#   'month': 'September',
#   'year': 2003,
#   'maxWind': 165,
#   'areas': ['Greater Antilles', 'Bahamas', 'Eastern United States', 'Ontario'],
#   'damage': 5370000000.0,
#   'deaths': 51},
#  'Ivan': {'name': 'Ivan',
#   'month': 'September',
#   'year': 2004,
#   'maxWind': 165,
#   'areas': ['The Caribbean', 'Venezuela', 'United States Gulf Coast'],
#   'damage': 23300000000.0,
#   'deaths': 124},
#  'Emily': {'name': 'Emily',
#   'month': 'July',
#   'year': 2005,
#   'maxWind': 160,
#   'areas': ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'],
#   'damage': 1010000000.0,
#   'deaths': 17},
#  'Katrina': {'name': 'Katrina',
#   'month': 'August',
#   'year': 2005,
#   'maxWind': 175,
#   'areas': ['Bahamas', 'United States Gulf Coast'],
#   'damage': 125000000000.0,
#   'deaths': 1836},
#  'Rita': {'name': 'Rita',
#   'month': 'September',
#   'year': 2005,
#   'maxWind': 180,
#   'areas': ['Cuba', 'United States Gulf Coast'],
#   'damage': 12000000000.0,
#   'deaths': 125},
#  'Wilma': {'name': 'Wilma',
#   'month': 'October',
#   'year': 2005,
#   'maxWind': 185,
#   'areas': ['Greater Antilles', 'Central America', 'Florida'],
#   'damage': 29400000000.0,
#   'deaths': 87},
#  'Dean': {'name': 'Dean',
#   'month': 'August',
#   'year': 2007,
#   'maxWind': 175,
#   'areas': ['The Caribbean', 'Central America'],
#   'damage': 1760000000.0,
#   'deaths': 45},
#  'Felix': {'name': 'Felix',
#   'month': 'September',
#   'year': 2007,
#   'maxWind': 175,
#   'areas': ['Nicaragua', 'Honduras'],
#   'damage': 720000000.0,
#   'deaths': 133},
#  'Matthew': {'name': 'Matthew',
#   'month': 'October',
#   'year': 2016,
#   'maxWind': 165,
#   'areas': ['Antilles',
#    'Venezuela',
#    'Colombia',
#    'United States East Coast',
#    'Atlantic Canada'],
#   'damage': 15100000000.0,
#   'deaths': 603},
#  'Irma': {'name': 'Irma',
#   'month': 'September',
#   'year': 2017,
#   'maxWind': 180,
#   'areas': ['Cape Verde',
#    'The Caribbean',
#    'British Virgin Islands',
#    'U.S. Virgin Islands',
#    'Cuba',
#    'Florida'],
#   'damage': 64800000000.0,
#   'deaths': 138},
#  'Maria': {'name': 'Maria',
#   'month': 'September',
#   'year': 2017,
#   'maxWind': 175,
#   'areas': ['Lesser Antilles',
#    'Virgin Islands',
#    'Puerto Rico',
#    'Dominican Republic',
#    'Turks and Caicos Islands'],
#   'damage': 91600000000.0,
#   'deaths': 3057},
#  'Michael': {'name': 'Michael',
#   'month': 'October',
#   'year': 2018,
#   'maxWind': 160,
#   'areas': ['Central America',
#    'United States Gulf Coast (especially Florida Panhandle)'],
#   'damage': 25100000000.0,
#   'deaths': 74}}
